# %% [markdown]
# # Challenge Questions - Employees Dataset

# %% [markdown]
# # Instructions:
# • Please ensure you don't overwrite any existing cells. Add new cells below by pressing ALT+ENTER
#
# • Attempt all of the questions
#
# • You are encouraged to look online for help should you need it

# %% [markdown]
# # Dataset overview:
# There are three csv files containing tables stored in the same directory as this Notebook, they are all related to each other:
#
# • **employees.csv**: contains information about employees in a company. It contains their unique employee number (emp_no), their department number (dept_no), their hire date (hire_date) and their leaving date (leaving_date). The leaving date is blank if the employee is still employed by the company
#
# • **departments.csv**: This contains information about the departments in a company. It contains the deparment number (dept_no), the department name (dept_name) and location.
#
# • **salaries.csv**: This file contains the salaries of the employees. It contains a unique employee department key (emp_dept_key) and the salary. The emp_dept_key is in the format 'emp_id-dept_id'

# %% [markdown]
# #

# %% [markdown]
# ## Import pandas, numpy and datetime

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ## Load the files:
# • "employees.csv" should be assigned to the variable **emp**
#
# • "departments.csv" should be assigned to the variable **dept**
#
# • "salaries.csv" should be assigned to the variable **sal**

# %%
emp=pd.read_csv("employees.csv")
dept=pd.read_csv("departments.csv")
sal=pd.read_csv("salaries.csv")

# %% [markdown]
# ## Check the head of all three DataFrames

# %%
emp.head()
# Out:
#    emp_no dept_no   hire_date leaving_date
# 0   10001      D5  26/06/2006          NaN
# 1   10002      D6  21/11/2005          NaN
# 2   10003      D4  28/08/2006          NaN
# 3   10004      D4  01/12/2006          NaN
# 4   10005      D3  12/09/2009          NaN

# %%
dept.head()
# Out:
#   dept_no                dept_name  location
# 0      D1   Accounting and Finance   Chicago
# 1      D2          Human Resources  New York
# 2      D3  Supply Chain Operations   Chicago
# 3      D4                Marketing  New York
# 4      D5               Technology   Chicago

# %%
sal.head()
# Out:
#   emp_dept_key  salary
# 0     10001-D5   30546
# 1     10002-D6   36536
# 2     10003-D4   38323
# 3     10004-D4   31851
# 4     10005-D3   53435

# %% [markdown]
# ## Check the data types of all three DataFrames

# %%
emp.dtypes
# Out:
# emp_no           int64
# dept_no         object
# hire_date       object
# leaving_date    object
# dtype: object

# %%
dept.dtypes
# Out:
# dept_no      object
# dept_name    object
# location     object
# dtype: object

# %%
sal.dtypes
# Out:
# emp_dept_key    object
# salary           int64
# dtype: object

# %% [markdown]
# ## Change the data types accordingly.
#
# • emp_no, dept_no, dept_name, location, emp_depy_key should all be string data types
#
# • hire_date and leaving_date should be datetime64
#
# • salary should be int64

# %%
emp[['emp_no', 'dept_no']] = emp[['emp_no', 'dept_no']].astype('string')

# %%
# dept_no is also in the dept Dataframe
dept[['dept_name','location','dept_no']]=dept[['dept_name','location','dept_no']].astype('string')

# %%
sal['emp_dept_key']=sal['emp_dept_key'].astype('string')

# %%
# For dates you cannot combine for different columns as above
emp['hire_date']=pd.to_datetime(emp['hire_date'],format='%d/%m/%Y')

# %%
emp['leaving_date']=pd.to_datetime(emp['leaving_date'],format='%d/%m/%Y')

# %%
sal['salary']=sal['salary'].astype(int)

# %%
emp.dtypes
# Out:
# emp_no          string[python]
# dept_no         string[python]
# hire_date       datetime64[ns]
# leaving_date    datetime64[ns]
# dtype: object

# %%
dept.dtypes
# Out:
# dept_no      string[python]
# dept_name    string[python]
# location     string[python]
# dtype: object

# %%
sal.dtypes
# Out:
# emp_dept_key    string[python]
# salary                   int32
# dtype: object

# %% [markdown]
# ## How many employees are currently working at the company.
#
# The employees still employed do not have a leaving date value. You can use the isnull() method to identify nulls or NaN values.
#
# isnull(): https://pandas.pydata.org/docs/reference/api/pandas.isnull.html

# %%
emp['leaving_date'].isnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997    False
# 998    False
# 999     True
# Name: leaving_date, Length: 1000, dtype: bool

# %%
# You MUST first filter the dataset before counting otherwise it will count all elements in that column irregardless of whether True or false
emp[emp['leaving_date'].isnull()].count()
# Out:
# emp_no          741
# dept_no         741
# hire_date       741
# leaving_date      0
# dtype: int64

# %%
# We can remove uncessary columns by referencing the column we want to keep
emp[emp['leaving_date'].isnull()].count()['emp_no']
# Out:
# 741

# %%
#Alternatively
len(emp[emp['leaving_date'].isnull()])
# Out:
# 741

# %% [markdown]
# ## How many currently employed people are there per department.

# %%
emp[emp['leaving_date'].isnull()].groupby(by='dept_no').count()
# Out:
#          emp_no  hire_date  leaving_date
# dept_no
# D1           84         84             0
# D2           36         36             0
# D3           94         94             0
# D4          171        171             0
# D5          188        188             0
# D6          168        168             0

# %%
# Hiding uncessary columns,this time using drop
emp[emp['leaving_date'].isnull()].groupby(by='dept_no').count().drop(columns=['hire_date','leaving_date'])
# Out:
#          emp_no
# dept_no
# D1           84
# D2           36
# D3           94
# D4          171
# D5          188
# D6          168

# %%
# Using a pivot table
# writing the same column in both the values and columns arguements results in an error 
# so, just ignore the column arguement if the column needs to appear as both a column and provides the cell values
emp[emp['leaving_date'].isnull()].pivot_table(values='emp_no',aggfunc='count',index='dept_no',columns='emp_no')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[367], line 4
#       1 # Using a pivot table
#       2 # writing the same column in both the values and columns arguements results in an error
#       3 # so, just ignore the column arguement if the column needs to appear as both a column and provides the cell values
# ----> 4 emp[emp['leaving_date'].isnull()].pivot_table(values='emp_no',aggfunc='count',index='dept_no',columns='emp_no')
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
#    8585         fill_value=fill_value,
#    8586         margins=margins,
#    8587         dropna=dropna,
#    8588         margins_name=margins_name,
#    8589         observed=observed,
#    8590         sort=sort,
#    8591     )
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\reshape\pivot.py:166, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     163             pass
#     164     values = list(values)
# --> 166 grouped = data.groupby(keys, observed=observed, sort=sort)
#     167 agged = grouped.agg(aggfunc)
#     169 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\pandas\core\groupby\grouper.py:980, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     976     in_axis, name, gpr = True, gpr, obj[gpr]
#     977     if gpr.ndim != 1:
#     978         # non-unique columns; raise here to get the name in the
#     979         # exception message
# --> 980         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     981     exclusions.add(name)
#     982 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'emp_no' not 1-dimensional

# %%
emp[emp['leaving_date'].isnull()].pivot_table(values='emp_no',aggfunc='count',index='dept_no')
# Out:
#          emp_no
# dept_no
# D1           84
# D2           36
# D3           94
# D4          171
# D5          188
# D6          168

# %% [markdown]
# ## Perform a left join on the emp and dept DataFrames (with emp as the left DF). Assign the result of this to the variable emp_dept

# %%
emp_dept=pd.merge(left= emp, right= dept, left_on='dept_no', right_on='dept_no',how='left')

# %%
emp_dept
# Out:
#     emp_no dept_no  hire_date leaving_date                dept_name  location
# 0    10001      D5 2006-06-26          NaT               Technology   Chicago
# 1    10002      D6 2005-11-21          NaT                    Sales   Chicago
# 2    10003      D4 2006-08-28          NaT                Marketing  New York
# 3    10004      D4 2006-12-01          NaT                Marketing  New York
# 4    10005      D3 2009-09-12          NaT  Supply Chain Operations   Chicago
# ..     ...     ...        ...          ...                      ...       ...
# 995  10903      D1 2009-02-14          NaT   Accounting and Finance   Chicago
# 996  10904      D5 2013-04-16          NaT               Technology   Chicago
# 997  10905      D4 2005-02-28   2006-03-07                Marketing  New York
# 998  10906      D2 2014-01-20   2021-04-25          Human Resources  New York
# 999  10906      D6 2014-01-20          NaT                    Sales   Chicago
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## Perform a left join on the newly created "emp_dept" DataFrame and the "sal" DataFrame.
# ## Assign this resulting DataFrame to the variable "emp_dept_sal"
#
# • You will need to think about how to join the two tables. Note the emp_dept_key on the sal DataFrame is in the format 'emp_id-dept_id'

# %%
# the primary_key in the sal Datframe is in the format 'emp_id-dept_id' thus, we have to create a column similar to it to join them on
emp_dept['new_key']=emp_dept['emp_no']+'-'+emp_dept['dept_no']

# %%
emp_dept
# Out:
#     emp_no dept_no  hire_date leaving_date                dept_name  location  \
# 0    10001      D5 2006-06-26          NaT               Technology   Chicago
# 1    10002      D6 2005-11-21          NaT                    Sales   Chicago
# 2    10003      D4 2006-08-28          NaT                Marketing  New York
# 3    10004      D4 2006-12-01          NaT                Marketing  New York
# 4    10005      D3 2009-09-12          NaT  Supply Chain Operations   Chicago
# ..     ...     ...        ...          ...                      ...       ...
# 995  10903      D1 2009-02-14          NaT   Accounting and Finance   Chicago
# 996  10904      D5 2013-04-16          NaT               Technology   Chicago
# 997  10905      D4 2005-02-28   2006-03-07                Marketing  New York
# 998  10906      D2 2014-01-20   2021-04-25          Human Resources  New York
# 999  10906      D6 2014-01-20          NaT                    Sales   Chicago
#
#       new_key
# 0    10001-D5
# 1    10002-D6
# 2    10003-D4
# 3    10004-D4
# 4    10005-D3
# ..        ...
# 995  10903-D1
# 996  10904-D5
# 997  10905-D4
# 998  10906-D2
# 999  10906-D6
#
# [1000 rows x 7 columns]

# %%
emp_dept_sal=pd.merge(left=emp_dept,right=sal,left_on='new_key',right_on='emp_dept_key',how='left')

# %%
emp_dept_sal
# Out:
#      emp_no dept_no  hire_date leaving_date                dept_name  \
# 0     10001      D5 2006-06-26          NaT               Technology
# 1     10002      D6 2005-11-21          NaT                    Sales
# 2     10003      D4 2006-08-28          NaT                Marketing
# 3     10004      D4 2006-12-01          NaT                Marketing
# 4     10005      D3 2009-09-12          NaT  Supply Chain Operations
# ...     ...     ...        ...          ...                      ...
# 997   10903      D1 2009-02-14          NaT   Accounting and Finance
# 998   10904      D5 2013-04-16          NaT               Technology
# 999   10905      D4 2005-02-28   2006-03-07                Marketing
# 1000  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1001  10906      D6 2014-01-20          NaT                    Sales
#
#       location   new_key emp_dept_key  salary
# 0      Chicago  10001-D5     10001-D5   30546
# 1      Chicago  10002-D6     10002-D6   36536
# 2     New York  10003-D4     10003-D4   38323
# 3     New York  10004-D4     10004-D4   31851
# 4      Chicago  10005-D3     10005-D3   53435
# ...        ...       ...          ...     ...
# 997    Chicago  10903-D1     10903-D1   42815
# 998    Chicago  10904-D5     10904-D5   90778
# 999   New York  10905-D4     10905-D4   32735
# 1000  New York  10906-D2     10906-D2   29095
# 1001   Chicago  10906-D6     10906-D6   97330
#
# [1002 rows x 9 columns]

# %% [markdown]
# <b>Note: we have 1002 rows

# %%
emp_dept_sal['new_key'].value_counts()
# Out:
# new_key
# 10259-D1    4
# 10013-D3    1
# 10029-D4    1
# 10028-D5    1
# 10003-D4    1
#            ..
# 10902-D5    1
# 10903-D1    1
# 10904-D5    1
# 10905-D4    1
# 10906-D6    1
# Name: count, Length: 999, dtype: Int64

# %% [markdown]
# <b>We could have gone the other way by breaking up emp_dept_key in the sal department

# %%
# We can use lambda and apply to slice the emp_dept_key column values
sal['emp_no1']=sal['emp_dept_key'].apply(lambda x :x[:5])

# %%
sal
# Out:
#     emp_dept_key  salary emp_no1
# 0       10001-D5   30546   10001
# 1       10002-D6   36536   10002
# 2       10003-D4   38323   10003
# 3       10004-D4   31851   10004
# 4       10005-D3   53435   10005
# ..           ...     ...     ...
# 995     10903-D1   42815   10903
# 996     10904-D5   90778   10904
# 997     10905-D4   32735   10905
# 998     10906-D2   29095   10906
# 999     10906-D6   97330   10906
#
# [1000 rows x 3 columns]

# %%
# A more robust situation would be to use the find method to locate the index number of the '-' seperator
sal['emp_no1']=sal['emp_dept_key'].apply(lambda x :x[:x.find('-')]) # x[0:x.find('-')]
                                                                    # this means start at 0 then go till '-' is found
                                                                    #Recall: find is a string method

# This is the go to method for long ids

# %%
sal
# Out:
#     emp_dept_key  salary emp_no1
# 0       10001-D5   30546   10001
# 1       10002-D6   36536   10002
# 2       10003-D4   38323   10003
# 3       10004-D4   31851   10004
# 4       10005-D3   53435   10005
# ..           ...     ...     ...
# 995     10903-D1   42815   10903
# 996     10904-D5   90778   10904
# 997     10905-D4   32735   10905
# 998     10906-D2   29095   10906
# 999     10906-D6   97330   10906
#
# [1000 rows x 3 columns]

# %%
emp_dept_sal=pd.merge(left=emp_dept,right=sal,left_on='emp_no', right_on = 'emp_no1', how='left')

# %%
emp_dept_sal
# Out:
#      emp_no dept_no  hire_date leaving_date                dept_name  \
# 0     10001      D5 2006-06-26          NaT               Technology
# 1     10002      D6 2005-11-21          NaT                    Sales
# 2     10003      D4 2006-08-28          NaT                Marketing
# 3     10004      D4 2006-12-01          NaT                Marketing
# 4     10005      D3 2009-09-12          NaT  Supply Chain Operations
# ...     ...     ...        ...          ...                      ...
# 1183  10905      D4 2005-02-28   2006-03-07                Marketing
# 1184  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1185  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1186  10906      D6 2014-01-20          NaT                    Sales
# 1187  10906      D6 2014-01-20          NaT                    Sales
#
#       location   new_key emp_dept_key  salary emp_no1
# 0      Chicago  10001-D5     10001-D5   30546   10001
# 1      Chicago  10002-D6     10002-D6   36536   10002
# 2     New York  10003-D4     10003-D4   38323   10003
# 3     New York  10004-D4     10004-D4   31851   10004
# 4      Chicago  10005-D3     10005-D3   53435   10005
# ...        ...       ...          ...     ...     ...
# 1183  New York  10905-D4     10905-D4   32735   10905
# 1184  New York  10906-D2     10906-D2   29095   10906
# 1185  New York  10906-D2     10906-D6   97330   10906
# 1186   Chicago  10906-D6     10906-D2   29095   10906
# 1187   Chicago  10906-D6     10906-D6   97330   10906
#
# [1188 rows x 10 columns]

# %% [markdown]
# <b> Note:we have 1188 rows

# %%
emp_dept_sal['emp_dept_key'].value_counts()
# Out:
# emp_dept_key
# 10259-D1    4
# 10440-D3    2
# 10088-D1    2
# 10836-D1    2
# 10855-D6    2
#            ..
# 10713-D3    1
# 10714-D5    1
# 10715-D4    1
# 10716-D5    1
# 10454-D6    1
# Name: count, Length: 999, dtype: Int64

# %% [markdown]
#     As you can see the methods bring different results.Why? I am not sure yet.

# %% [markdown]
# ## Drop the column "emp_dept_key"

# %%
emp_dept_sal.drop(columns='emp_dept_key',inplace=True)

# %%
emp_dept_sal
# Out:
#      emp_no dept_no  hire_date leaving_date                dept_name  \
# 0     10001      D5 2006-06-26          NaT               Technology
# 1     10002      D6 2005-11-21          NaT                    Sales
# 2     10003      D4 2006-08-28          NaT                Marketing
# 3     10004      D4 2006-12-01          NaT                Marketing
# 4     10005      D3 2009-09-12          NaT  Supply Chain Operations
# ...     ...     ...        ...          ...                      ...
# 1183  10905      D4 2005-02-28   2006-03-07                Marketing
# 1184  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1185  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1186  10906      D6 2014-01-20          NaT                    Sales
# 1187  10906      D6 2014-01-20          NaT                    Sales
#
#       location   new_key  salary emp_no1
# 0      Chicago  10001-D5   30546   10001
# 1      Chicago  10002-D6   36536   10002
# 2     New York  10003-D4   38323   10003
# 3     New York  10004-D4   31851   10004
# 4      Chicago  10005-D3   53435   10005
# ...        ...       ...     ...     ...
# 1183  New York  10905-D4   32735   10905
# 1184  New York  10906-D2   29095   10906
# 1185  New York  10906-D2   97330   10906
# 1186   Chicago  10906-D6   29095   10906
# 1187   Chicago  10906-D6   97330   10906
#
# [1188 rows x 9 columns]

# %% [markdown]
# ## What is the average salary per department?

# %%
emp_dept_sal[['dept_name','salary']].groupby(by='dept_name').mean()
# Out:
#                                salary
# dept_name
# Accounting and Finance   52148.887324
# Human Resources          44849.602740
# Marketing                41540.041985
# Sales                    59192.053640
# Supply Chain Operations  45183.788462
# Technology               58975.979592

# %%
# Using a pivot table
emp_dept_sal.pivot_table(values='salary',index='dept_name',aggfunc='mean')
# Out:
#                                salary
# dept_name
# Accounting and Finance   52148.887324
# Human Resources          44849.602740
# Marketing                41540.041985
# Sales                    59192.053640
# Supply Chain Operations  45183.788462
# Technology               58975.979592

# %% [markdown]
# <b> This are values using the second method of merging from the previous question.

# %% [markdown]
# ## What is the average salary by location?

# %%
emp_dept_sal
# Out:
#      emp_no dept_no  hire_date leaving_date                dept_name  \
# 0     10001      D5 2006-06-26          NaT               Technology
# 1     10002      D6 2005-11-21          NaT                    Sales
# 2     10003      D4 2006-08-28          NaT                Marketing
# 3     10004      D4 2006-12-01          NaT                Marketing
# 4     10005      D3 2009-09-12          NaT  Supply Chain Operations
# ...     ...     ...        ...          ...                      ...
# 1183  10905      D4 2005-02-28   2006-03-07                Marketing
# 1184  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1185  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1186  10906      D6 2014-01-20          NaT                    Sales
# 1187  10906      D6 2014-01-20          NaT                    Sales
#
#       location   new_key  salary emp_no1
# 0      Chicago  10001-D5   30546   10001
# 1      Chicago  10002-D6   36536   10002
# 2     New York  10003-D4   38323   10003
# 3     New York  10004-D4   31851   10004
# 4      Chicago  10005-D3   53435   10005
# ...        ...       ...     ...     ...
# 1183  New York  10905-D4   32735   10905
# 1184  New York  10906-D2   29095   10906
# 1185  New York  10906-D2   97330   10906
# 1186   Chicago  10906-D6   29095   10906
# 1187   Chicago  10906-D6   97330   10906
#
# [1188 rows x 9 columns]

# %%
emp_dept_sal[['location','salary']].groupby(by='location').mean()
# Out:
#                 salary
# location
# Chicago   55383.208675
# New York  42261.229851

# %%
# Using a pivot table
emp_dept_sal.pivot_table(values='salary',index='location',aggfunc='mean')
# Out:
#                 salary
# location
# Chicago   55383.208675
# New York  42261.229851

# %% [markdown]
# ## How many people were hired each year in each of the last 10 years?

# %%
emp_dept_sal
# Out:
#      emp_no dept_no  hire_date leaving_date                dept_name  \
# 0     10001      D5 2006-06-26          NaT               Technology
# 1     10002      D6 2005-11-21          NaT                    Sales
# 2     10003      D4 2006-08-28          NaT                Marketing
# 3     10004      D4 2006-12-01          NaT                Marketing
# 4     10005      D3 2009-09-12          NaT  Supply Chain Operations
# ...     ...     ...        ...          ...                      ...
# 1183  10905      D4 2005-02-28   2006-03-07                Marketing
# 1184  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1185  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1186  10906      D6 2014-01-20          NaT                    Sales
# 1187  10906      D6 2014-01-20          NaT                    Sales
#
#       location   new_key  salary emp_no1
# 0      Chicago  10001-D5   30546   10001
# 1      Chicago  10002-D6   36536   10002
# 2     New York  10003-D4   38323   10003
# 3     New York  10004-D4   31851   10004
# 4      Chicago  10005-D3   53435   10005
# ...        ...       ...     ...     ...
# 1183  New York  10905-D4   32735   10905
# 1184  New York  10906-D2   29095   10906
# 1185  New York  10906-D2   97330   10906
# 1186   Chicago  10906-D6   29095   10906
# 1187   Chicago  10906-D6   97330   10906
#
# [1188 rows x 9 columns]

# %%
emp_dept_sal['ordered_hire_date']=sorted(emp_dept_sal['hire_date'])

# %%
# Viewing which years were the last 10 years
emp_dept_sal['ordered_years']=emp_dept_sal['ordered_hire_date'].dt.year

# %%
emp_dept_sal
# Out:
#      emp_no dept_no  hire_date leaving_date                dept_name  \
# 0     10001      D5 2006-06-26          NaT               Technology
# 1     10002      D6 2005-11-21          NaT                    Sales
# 2     10003      D4 2006-08-28          NaT                Marketing
# 3     10004      D4 2006-12-01          NaT                Marketing
# 4     10005      D3 2009-09-12          NaT  Supply Chain Operations
# ...     ...     ...        ...          ...                      ...
# 1183  10905      D4 2005-02-28   2006-03-07                Marketing
# 1184  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1185  10906      D2 2014-01-20   2021-04-25          Human Resources
# 1186  10906      D6 2014-01-20          NaT                    Sales
# 1187  10906      D6 2014-01-20          NaT                    Sales
#
#       location   new_key  salary emp_no1 ordered_hire_date  ordered_years
# 0      Chicago  10001-D5   30546   10001        2005-02-03           2005
# 1      Chicago  10002-D6   36536   10002        2005-02-14           2005
# 2     New York  10003-D4   38323   10003        2005-02-15           2005
# 3     New York  10004-D4   31851   10004        2005-02-18           2005
# 4      Chicago  10005-D3   53435   10005        2005-02-18           2005
# ...        ...       ...     ...     ...               ...            ...
# 1183  New York  10905-D4   32735   10905        2019-03-30           2019
# 1184  New York  10906-D2   29095   10906        2019-03-30           2019
# 1185  New York  10906-D2   97330   10906        2019-03-30           2019
# 1186   Chicago  10906-D6   29095   10906        2019-04-30           2019
# 1187   Chicago  10906-D6   97330   10906        2019-10-28           2019
#
# [1188 rows x 11 columns]

# %%
# Viewing a list of all the years 
emp_dept_sal['ordered_years'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019])

# %%
# Viewing a list of the last 10 years 
emp_dept_sal['ordered_years'].unique()[-10:]
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
# filtering the dataset so it only contains values from these years
emp_dept_sal[(emp_dept_sal['ordered_years'] >=2010) & (emp_dept_sal['ordered_years'] <=2019)]
# Out:
#      emp_no dept_no  hire_date leaving_date               dept_name  location  \
# 624   10478      D5 2012-06-09          NaT              Technology   Chicago
# 625   10478      D5 2012-06-09          NaT              Technology   Chicago
# 626   10478      D1 2012-06-09   2013-02-10  Accounting and Finance   Chicago
# 627   10478      D1 2012-06-09   2013-02-10  Accounting and Finance   Chicago
# 628   10479      D4 2007-02-28          NaT               Marketing  New York
# ...     ...     ...        ...          ...                     ...       ...
# 1183  10905      D4 2005-02-28   2006-03-07               Marketing  New York
# 1184  10906      D2 2014-01-20   2021-04-25         Human Resources  New York
# 1185  10906      D2 2014-01-20   2021-04-25         Human Resources  New York
# 1186  10906      D6 2014-01-20          NaT                   Sales   Chicago
# 1187  10906      D6 2014-01-20          NaT                   Sales   Chicago
#
#        new_key  salary emp_no1 ordered_hire_date  ordered_years
# 624   10478-D5   61674   10478        2010-01-03           2010
# 625   10478-D5   38519   10478        2010-01-05           2010
# 626   10478-D1   61674   10478        2010-01-05           2010
# 627   10478-D1   38519   10478        2010-01-05           2010
# 628   10479-D4   46793   10479        2010-01-05           2010
# ...        ...     ...     ...               ...            ...
# 1183  10905-D4   32735   10905        2019-03-30           2019
# 1184  10906-D2   29095   10906        2019-03-30           2019
# 1185  10906-D2   97330   10906        2019-03-30           2019
# 1186  10906-D6   29095   10906        2019-04-30           2019
# 1187  10906-D6   97330   10906        2019-10-28           2019
#
# [564 rows x 11 columns]

# %%
# using a pivot table
emp_dept_sal[(emp_dept_sal['ordered_years'] >=2010) & (emp_dept_sal['ordered_years'] <=2019)].pivot_table(
    index='ordered_years',values='emp_no',aggfunc='count')
# Out:
#                emp_no
# ordered_years
# 2010              146
# 2011               99
# 2012               81
# 2013               61
# 2014               69
# 2015               39
# 2016               40
# 2017               14
# 2018                8
# 2019                7

# %%
# using group by
emp_dept_sal[(emp_dept_sal['ordered_years'] >=2010) & (emp_dept_sal['ordered_years'] <=2019)].groupby(by='ordered_years').count()
# Out:
#                emp_no  dept_no  hire_date  leaving_date  dept_name  location  \
# ordered_years
# 2010              146      146        146            43        146       146
# 2011               99       99         99            27         99        99
# 2012               81       81         81            23         81        81
# 2013               61       61         61            24         61        61
# 2014               69       69         69            18         69        69
# 2015               39       39         39            11         39        39
# 2016               40       40         40            12         40        40
# 2017               14       14         14             6         14        14
# 2018                8        8          8             2          8         8
# 2019                7        7          7             3          7         7
#
#                new_key  salary  emp_no1  ordered_hire_date
# ordered_years
# 2010               146     146      146                146
# 2011                99      99       99                 99
# 2012                81      81       81                 81
# 2013                61      61       61                 61
# 2014                69      69       69                 69
# 2015                39      39       39                 39
# 2016                40      40       40                 40
# 2017                14      14       14                 14
# 2018                 8       8        8                  8
# 2019                 7       7        7                  7

# %%
# dropping uncessary columns
emp_dept_sal[(emp_dept_sal['ordered_years'] >=2010) & (emp_dept_sal['ordered_years'] <=2019)].groupby(
    by='ordered_years').count()['emp_no']
# Out:
# ordered_years
# 2010    146
# 2011     99
# 2012     81
# 2013     61
# 2014     69
# 2015     39
# 2016     40
# 2017     14
# 2018      8
# 2019      7
# Name: emp_no, dtype: int64

# %% [markdown]
# <b> A much shorter alternative is than filtering is to use the tail(10)  the dataset 😅😅

# %%
emp_dept_sal.groupby(by='ordered_years').count().tail(10)
# Out:
#                emp_no  dept_no  hire_date  leaving_date  dept_name  location  \
# ordered_years
# 2010              146      146        146            43        146       146
# 2011               99       99         99            27         99        99
# 2012               81       81         81            23         81        81
# 2013               61       61         61            24         61        61
# 2014               69       69         69            18         69        69
# 2015               39       39         39            11         39        39
# 2016               40       40         40            12         40        40
# 2017               14       14         14             6         14        14
# 2018                8        8          8             2          8         8
# 2019                7        7          7             3          7         7
#
#                new_key  salary  emp_no1  ordered_hire_date
# ordered_years
# 2010               146     146      146                146
# 2011                99      99       99                 99
# 2012                81      81       81                 81
# 2013                61      61       61                 61
# 2014                69      69       69                 69
# 2015                39      39       39                 39
# 2016                40      40       40                 40
# 2017                14      14       14                 14
# 2018                 8       8        8                  8
# 2019                 7       7        7                  7

# %%
emp_dept_sal.groupby(by='ordered_years').count().tail(10)['emp_no']
# Out:
# ordered_years
# 2010    146
# 2011     99
# 2012     81
# 2013     61
# 2014     69
# 2015     39
# 2016     40
# 2017     14
# 2018      8
# 2019      7
# Name: emp_no, dtype: int64

# %%
emp_dept_sal.pivot_table(index='ordered_years', aggfunc='count', values='emp_no').tail(10)
# Out:
#                emp_no
# ordered_years
# 2010              146
# 2011               99
# 2012               81
# 2013               61
# 2014               69
# 2015               39
# 2016               40
# 2017               14
# 2018                8
# 2019                7
